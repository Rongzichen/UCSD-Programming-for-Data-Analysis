# %%
from linkedin_api import Linkedin

# Authenticate using any Linkedin account credentials
api = Linkedin('abritten@ucsd.edu', 'Hello!11')

pro_list = []
n = 1
for p in p_list:
    if n >= 164:
        profile = api.get_profile(p)
        pro_list.append(profile)
    
    print(n, ' ', p)
    n+= 1
# Out:
# 1   lavanyasatyan
# 2   yawen-zhao-b5612b157
# 3   weiqi-xu-40354115a
# 4   wanjun-gu
# 5   lionellijian
# 6   zhoulin-chen-b35476192
# 7   syh031
# 8   bowei-e-8640b1112
# 9   yifan-xu-77a10146
# 10   yuxin-han-92aa0b157
# 11   meetluyao
# 12   dih024
# 13   ctrando
# 14   terryylin
# 15   chenweixie
# 16   yu-flora-shen-18b290133
# 17   nijianmo
# 18   junjie-lin
# 19   zheng-guo-694245124
# 20   rongrongmiao
# 21   albertyang0502
# 22   devyaanshu-patodia-003086115
# 23   sandervalstar
# 24   christopherbyeh
# 25   cheng-gong
# 26   garo-adjoian-a76634139
# 27   shuyang-mark-liu-84434b160
# 28   lorraine-shang-364390137
# 29   xuanru-zhu-969b4b135
# 30   sdillonhicks
# 31   lychengr3x
# 32   minghao-han-6ba54414b
# 33   junxiong-mao-08109487
# 34   chengyezhang
# 35   zi-he-71025013b
# 36   jiahong-garhom-li
# 37   kelvin-jiajian-lei-50788547
# 38   zhenan-david-yin-a0358a136
# 39   patrickshyu
# 40   ramon-dioneda-2b2b65127
# 41   yaohui-lu-260030176
# 42   colin-van-winkle-836b4972
# 43   yuting-wang-73137374
# 44   aliciaisabel
# 45   roshan-fernando
# 46   yuqing-deng
# 47   zhshao
# 48   kevin-seyedan-bab8a1190
# 49   riccardo-zerilli-092914126
# 50   skumar3099
# 51   peng-philip-yan-048360a0
# 52   jessy-ayala
# 53   tiffany-loo
# 54   shenghao-jiang-b57157118
# 55   joseph-c-ho
# 56   vivianfan-cs
# 57   yujian-mi
# 58   zhang-bowen
# 59   sanshit-sagar
# 60   adrian-mendoza-975938145
# 61   cwshoup
# 62   joe-jiang
# 63   agemawat
# 64   yixun-zhang-122637170
# 65   kmittal1
# 66   qiao-zhang-ba93139b
# 67   yifei-ning-246615170
# 68   rongqi-yan-84a680a6
# 69   ningwei95
# 70   david-dinata
# 71   shengboge
# 72   kaiqi-yao
# 73   zheng-qu-a62a8a13a
# 74   zhipeng-yao-258645113
# 75   jialun-lyu-00180416b
# 76   xinyanzhangsherry
# 77   williambui
# 78   pengzhiwang
# 79   elvishelvisshi
# 80   qiyuchen7
# 81   ethan-lan-b14406149
# 82   jingyang-li-53a910170
# 83   richard-yu
# 84   amritakohli
# 85   nguyenhachuy
# 86   san-kang
# 87   orralexander
# 88   deqian-kong-0559095a
# 89   xiaochenli99
# 90   jiayi-li-639001105
# 91   john-l-693b7915a
# 92   ravneet-d-a0a767146
# 93   yu-feng-107
# 94   martin-mourgos
# 95   zhipeng-yan-776849a6
# 96   yuting-jiang-b2250a179
# 97   jerald-barker-certified-scrum-master-pmp-22926a6
# 98   xinyue-ou
# 99   chenchenvc
# 100   ruchen-zhen
# 101   tomatosliu
# 102   dichen-qian-236524103
# 103   fan-duo
# 104   sachikanda211
# 105   yiman-mao-15751b88
# 106   tong-jiang-27098536
# 107   xinyun-liu
# 108   wentao-wei
# 109   jonathanwickes
# 110   yufeng-gao-b27b07164
# 111   fanjin-zeng
# 112   siwei-jason-xie
# 113   zijunzhao-zzj
# 114   zhuo-chen-7407b8132
# 115   hongxiang-jiang-3558ba191
# 116   mikelinchu
# 117   edward-wong-5a92a988
# 118   mo-
# 119   amritansh-gupta
# 120   luzanne-batoon
# 121   yunhan-tang-94aa1514b
# 122   jiayuan-kong-a48652134
# 123   %E5%BD%A6%E6%B8%85-%E7%A8%8B-037652b6
# 124   amanda-song-m
# 125   alexander-ali-206549164
# 126   habemusne
# 127   nadahfeteih
# 128   hongquan-zhang-22bb9a193
# 129   jianing-zhang-ucsd
# 130   xiaoxiaofan
# 131   richard-tran-ab4053a7
# 132   zhimin-lin-902140133
# 133   b1deng
# 134   yangwenyi-jing-wendy
# 135   kailing-ding
# 136   sneha-naren
# 137   ling-hong-63155216a
# 138   yantingemma
# 139   kimjaspermui
# 140   yunhan-ma
# 141   qingzhuo-judy-liu
# 142   che-yu-499257158
# 143   jichen-hong
# 144   holunwu
# 145   diyuan-sarah-xue-47106b159
# 146   qi-ma
# 147   suli-huang-25087bb3
# 148   kai-wang-1155b064
# 149   hengyu-zhao-479b51148
# 150   yu-wun-wang-5b8830166
# 151   yilun-zhang-269b4577
# 152   sikai-liu-113134131
# 153   shayan-raisi-70bb08174
# 154   yyan
# 155   rong-xi
# 156   qiyuan-wu-888188119
# 157   tigernguyen
# 158   zhibo-chen-8052a7133
# 159   sideli
# 160   deling-li-70a546126
# 161   qingtao-sun-16b727136
# 162   janet-lin-2610
# 163   hilda-liu
# 164   haofan-wu
# 165   chen-guanyu-970405
# 166   yujing-shen-491861154
# 167   melvingeorgein
# 168   hiredaviddai
# 169   qisen-zhou-65885bb7
# 170   hanxiao-he-383847149
# 171   byshen
# 172   zheng-shan
# 173   li-an-yang
# 174   kmguo13
# 175   zhuoqun-xu
# 176   bosi-cheng-62338416b
# 177   yang-rui-6aa1ab140
# 178   ke-xiao-7786ba116
# 179   yue-zhou-092854118
# 180   pyae-maung-89a99194
# 181   brianngyn
# 182   chengzhu-duan
# 183   subhankar-panda
# 184   runze-xu-9972a7171
# 185   max-bking-63597a187
# 186   yessenbayev
# 187   cheng-peng-675a83177
# 188   haoshen-hong-266652118
# 189   roy-yidong-luo-90809014a
# 190   wenting-zhao
# 191   rvyuan
# 192   xi-chen-4b500714b
# 193   leo-sc-ku
# 194   bert-haddad-0b6b0bb1
# 195   patrick-hayes-471111105
# 196   song-lu-b4b64130
# 197   haochengli
# 198   niemamoshiri
# 199   irisziyiwang
# 200   fan-qian
# 201   carrie-xia-016662139
# 202   xueyang-li-24090183
# 203   mengmeng-chen-2b22a0161
# 204   yili-cse-ucsd
# 205   weiranxiong
# 206   heather-limj
# 207   yayi-guo-76a463123
# 208   jiageng-zhang
# 209   xuzhaoqing
# 210   hang-zhang-189579178
# 211   yucheng-bian-24151614b
# 212   jinmouli
# 213   yuepeng-shen-8b1743193
# 214   darryl-hua
# 215   haomin-wang-a67a7ab5
# 216   chunyi-tu
# 217   yiwen-li-47a019119
# 218   binglin-zhao-lynn
# 219   raissa-antoinette-a87731158
# 220   sw-si-wu
# 221   chenghao-tsai-46678a141
# 222   bo-chen-422836153
# 223   joshua-comes
# 224   lixiang-ao-87140051
# 225   safa-raffo
# 226   russellxie7
# 227   maniknarang
# 228   dian-yu-623226139
# 229   joe-yuxiao-zhou-49579a96
# 230   ygarde
# 231   bettyzhou0915
# 232   zhongzhi-li-403a26b0
# 233   chun-jhen-lai-03196b173
# 234   fanhillary
# 235   tianyinxu
# 236   jiaxuan-ren-7b3a41171
# 237   kimberlycarreon
# 238   zijin-ari-fu-256a42129
# 239   tianyu-sun
# 240   jiawei-zhu
# 241   clarencextan
# 242   ping-tsung-hsu
# 243   alisabeth-rogers
# 244   zhenlin-zhang-780415149
# 245   yuqi-zheng-28bba992
# 246   royalhien
# 247   juiyuchang
# 248   olivia-thai
# 249   yifanxuvanessa
# 250   haoming-zhang-ba3010156
# 251   xianze-meng-190ba2b0
# 252   xuhao-luo-611056162
# 253   jinhao-tang-26276a144
# 254   yujie-zhou-01616
# 255   jacelu0830
# 256   alan-kuo
# 257   weiweixiong
# 258   yu-xia-84769959
# 259   enhaocui
# 260   ting-yu-tiffany-chang-2527a4137
# 261   xingyu-gu
# 262   daletubat
# 263   zack-whz98
# 264   xinyuxie113
# 265   anxunwei
# 266   jonathanshamblen
# 267   james-christian-rich
# 268   lucas-nathan-982801159
# 269   michaelbaqadira
# 270   jianhui-wang-609287172
# 271   tianyi-lu-a34077191
# 272   harshp8l
# 273   juliamaemarkel
# 274   wongaimee
# 275   vanessa-chou-390b40a6
# 276   jin-wu
# 277   bodong-zhang-407706117
# 278   ziyi-wang-iris
# 279   yiwen-song-59682916b
# 280   sarthak-kaul-257679154
# 281   michael-hensen-02663b195
# 282   zijie-zhao
# 283   lijinchen
# 284   eric-fakhourian
# 285   mo-zhang-469a465a
# 286   stevengov
# 287   annanishere
# 288   william-jason-burns
# 289   laitn
# 290   mathurmadhav
# 291   penrose-pengluo-wang-56275b150
# 292   qian-zhang-qiz235
# 293   jianlingliu
# 294   catherine-f-xia
# 295   rui--xu
# 296   runyaochen
# 297   rishabh-malhotra-83aaa5130
# 298   siyu-lai-642736137
# 299   alfredwuy
# 300   jamshed-ashurov
# 301   emilyhuongnguyen
# 302   aveek-biswas
# 303   jingwen-yu-932933160
# 304   ashley-jiang-a9983b113
# 305   qianlong-qu-a8877b130
# 306   jiawei-zhou-2400
# 307   josephl310
# 308   yizhiyuan
# 309   teresa198906
# 310   leo-song-720a65103
# 311   mengjin-katherine-zhang-168865178
# 312   calvintjoeng
# 313   zhiqiang-pi
# 314   xinjin1994
# 315   patrick-salmas-58704b159
# 316   xu-li-577050127
# 317   ejung356
# 318   jiaxin-li-658b66a4
# 319   yiyun-shen
# 320   andreikhmel
# 321   zihan-zheng
# 322   n33
# 323   leejamesgh
# 324   renxu-hu
# 325   renjie-yu-00657220
# 326   yue-chen-b41626170
# 327   nick11roberts
# 328   yancen-pan-697b83143
# 329   fredgrier
# 330   evan-j-xue-501360105
# 331   bohuan-yang-6b10a514a
# 332   arvindsaripalli
# 333   dingcheng-hu-483b7a127
# 334   shiman-shannon-he
# 335   siman-wang-964316139
# 336   czhou29
# 337   qinyan-li-06098213b
# 338   r-deng
# 339   rongrong-liu-893526162
# 340   huilai-miao-326755150
# 341   zehao-xu
# 342   waynevnguyen
# 343   chaolicse
# 344   lishane31
# 345   tuoying-chen
# 346   jinzhao-feng-643327154
# 347   jiazhou-gao-8a661b148
# 348   shihao-luo-37a12a153
# 349   vincent8tong
# 350   lingfei-lu-414b54104
# 351   zhongjie-ren-5b2446156
# 352   wenrui-helena-li
# 353   dingmei
# 354   chu-ling-ko
# 355   xinrong-w-213b2711b
# 356   jiyuan-liu-ucsd
# 357   jiaming-zhang-a371a2152
# 358   qiuxin-sheng-206125b3
# 359   panqu
# 360   yuzhuzhang1
# 361   zhiqiang-sun
# 362   qingyu-zhou
# 363   nan-zhou-profile
# 364   yuanxin-li-9601
# 365   yangguang-he-5a7b54192
# 366   matthew-woods-1581718
# 367   fan-jin-248b9b189
# 368   yingwei-li-4b438765
# 369   devwu
# 370   xiqiang-ken-lin-a3a69a109
# 371   chongbinzhang
# 372   qihuan-ling
# 373   khurram-khakoo-76554049
# 374   han-chi
# 375   panthson
# 376   jiayi-wang-8abb2a156
# 377   anirudhperubotla
# 378   shike-zhang-8b270a173
# 379   sunyuzhuo
# 380   zhaochunma
# 381   chen-shijia-52630588
# 382   ysgcs
# 383   qing-zhang-ucsd
# 384   shen-liu-419b64109
# 385   yan-yi-53820311a
# 386   yuchun-jin
# 387   huiyingqu
# 388   mingyao-zheng
# 389   megan-kwok-193560172
# 390   paulo-gonzales
# 391   nikki-l-kuang
# 392   daphne-lyu
# 393   brentonang
# 394   jis
# 395   junchuan-wang-68906b59
# 396   fantasychen
# 397   yueeleng
# 398   ye-huang-3b9326118
# 399   yang-xu-45b910160
# 400   zikun-yang
# 401   zexi-chen-38412a153
# 402   chenweidai
# INFO:linkedin_api.linkedin:request failed: This profile can't be accessed
# 403   wentao-guan-6ab9a9122
# 404   changliangcao
# 405   mayu-zhao
# 406   komailrizvi
# 407   zheshanliu
# 408   ariane-tsai
# 409   zhaowei-cai-34991126
# 410   yu-zhong-78963296
# 411   jianxiongji
# 412   linfeng-tony-zheng
# 413   chris-weaver101
# 414   evawyf
# 415   yijun-olivia-he-33136a126

# %%
p_list = []
with open('profile_list_remains.txt', 'r') as f:
    lines = f.readlines()
    for line in lines:
        # GET a profile
        
        p_list.append(line.strip())

# %%
p_list
# Out:
# ['lavanyasatyan',
#  'yawen-zhao-b5612b157',
#  'weiqi-xu-40354115a',
#  'wanjun-gu',
#  'lionellijian',
#  'zhoulin-chen-b35476192',
#  'syh031',
#  'bowei-e-8640b1112',
#  'yifan-xu-77a10146',
#  'yuxin-han-92aa0b157',
#  'meetluyao',
#  'dih024',
#  'ctrando',
#  'terryylin',
#  'chenweixie',
#  'yu-flora-shen-18b290133',
#  'nijianmo',
#  'junjie-lin',
#  'zheng-guo-694245124',
#  'rongrongmiao',
#  'albertyang0502',
#  'devyaanshu-patodia-003086115',
#  'sandervalstar',
#  'christopherbyeh',
#  'cheng-gong',
#  'garo-adjoian-a76634139',
#  'shuyang-mark-liu-84434b160',
#  'lorraine-shang-364390137',
#  'xuanru-zhu-969b4b135',
#  'sdillonhicks',
#  'lychengr3x',
#  'minghao-han-6ba54414b',
#  'junxiong-mao-08109487',
#  'chengyezhang',
#  'zi-he-71025013b',
#  'jiahong-garhom-li',
#  'kelvin-jiajian-lei-50788547',
#  'zhenan-david-yin-a0358a136',
#  'patrickshyu',
#  'ramon-dioneda-2b2b65127',
#  'yaohui-lu-260030176',
#  'colin-van-winkle-836b4972',
#  'yuting-wang-73137374',
#  'aliciaisabel',
#  'roshan-fernando',
#  'yuqing-deng',
#  'zhshao',
#  'kevin-seyedan-bab8a1190',
#  'riccardo-zerilli-092914126',
#  'skumar3099',
#  'peng-philip-yan-048360a0',
#  'jessy-ayala',
#  'tiffany-loo',
#  'shenghao-jiang-b57157118',
#  'joseph-c-ho',
#  'vivianfan-cs',
#  'yujian-mi',
#  'zhang-bowen',
#  'sanshit-sagar',
#  'adrian-mendoza-975938145',
#  'cwshoup',
#  'joe-jiang',
#  'agemawat',
#  'yixun-zhang-122637170',
#  'kmittal1',
#  'qiao-zhang-ba93139b',
#  'yifei-ning-246615170',
#  'rongqi-yan-84a680a6',
#  'ningwei95',
#  'david-dinata',
#  'shengboge',
#  'kaiqi-yao',
#  'zheng-qu-a62a8a13a',
#  'zhipeng-yao-258645113',
#  'jialun-lyu-00180416b',
#  'xinyanzhangsherry',
#  'williambui',
#  'pengzhiwang',
#  'elvishelvisshi',
#  'qiyuchen7',
#  'ethan-lan-b14406149',
#  'jingyang-li-53a910170',
#  'richard-yu',
#  'amritakohli',
#  'nguyenhachuy',
#  'san-kang',
#  'orralexander',
#  'deqian-kong-0559095a',
#  'xiaochenli99',
#  'jiayi-li-639001105',
#  'john-l-693b7915a',
#  'ravneet-d-a0a767146',
#  'yu-feng-107',
#  'martin-mourgos',
#  'zhipeng-yan-776849a6',
#  'yuting-jiang-b2250a179',
#  'jerald-barker-certified-scrum-master-pmp-22926a6',
#  'xinyue-ou',
#  'chenchenvc',
#  'ruchen-zhen',
#  'tomatosliu',
#  'dichen-qian-236524103',
#  'fan-duo',
#  'sachikanda211',
#  'yiman-mao-15751b88',
#  'tong-jiang-27098536',
#  'xinyun-liu',
#  'wentao-wei',
#  'jonathanwickes',
#  'yufeng-gao-b27b07164',
#  'fanjin-zeng',
#  'siwei-jason-xie',
#  'zijunzhao-zzj',
#  'zhuo-chen-7407b8132',
#  'hongxiang-jiang-3558ba191',
#  'mikelinchu',
#  'edward-wong-5a92a988',
#  'mo-',
#  'amritansh-gupta',
#  'luzanne-batoon',
#  'yunhan-tang-94aa1514b',
#  'jiayuan-kong-a48652134',
#  '%E5%BD%A6%E6%B8%85-%E7%A8%8B-037652b6',
#  'amanda-song-m',
#  'alexander-ali-206549164',
#  'habemusne',
#  'nadahfeteih',
#  'hongquan-zhang-22bb9a193',
#  'jianing-zhang-ucsd',
#  'xiaoxiaofan',
#  'richard-tran-ab4053a7',
#  'zhimin-lin-902140133',
#  'b1deng',
#  'yangwenyi-jing-wendy',
#  'kailing-ding',
#  'sneha-naren',
#  'ling-hong-63155216a',
#  'yantingemma',
#  'kimjaspermui',
#  'yunhan-ma',
#  'qingzhuo-judy-liu',
#  'che-yu-499257158',
#  'jichen-hong',
#  'holunwu',
#  'diyuan-sarah-xue-47106b159',
#  'qi-ma',
#  'suli-huang-25087bb3',
#  'kai-wang-1155b064',
#  'hengyu-zhao-479b51148',
#  'yu-wun-wang-5b8830166',
#  'yilun-zhang-269b4577',
#  'sikai-liu-113134131',
#  'shayan-raisi-70bb08174',
#  'yyan',
#  'rong-xi',
#  'qiyuan-wu-888188119',
#  'tigernguyen',
#  'zhibo-chen-8052a7133',
#  'sideli',
#  'deling-li-70a546126',
#  'qingtao-sun-16b727136',
#  'janet-lin-2610',
#  'hilda-liu',
#  'haofan-wu',
#  'chen-guanyu-970405',
#  'yujing-shen-491861154',
#  'melvingeorgein',
#  'hiredaviddai',
#  'qisen-zhou-65885bb7',
#  'hanxiao-he-383847149',
#  'byshen',
#  'zheng-shan',
#  'li-an-yang',
#  'kmguo13',
#  'zhuoqun-xu',
#  'bosi-cheng-62338416b',
#  'yang-rui-6aa1ab140',
#  'ke-xiao-7786ba116',
#  'yue-zhou-092854118',
#  'pyae-maung-89a99194',
#  'brianngyn',
#  'chengzhu-duan',
#  'subhankar-panda',
#  'runze-xu-9972a7171',
#  'max-bking-63597a187',
#  'yessenbayev',
#  'cheng-peng-675a83177',
#  'haoshen-hong-266652118',
#  'roy-yidong-luo-90809014a',
#  'wenting-zhao',
#  'rvyuan',
#  'xi-chen-4b500714b',
#  'leo-sc-ku',
#  'bert-haddad-0b6b0bb1',
#  'patrick-hayes-471111105',
#  'song-lu-b4b64130',
#  'haochengli',
#  'niemamoshiri',
#  'irisziyiwang',
#  'fan-qian',
#  'carrie-xia-016662139',
#  'xueyang-li-24090183',
#  'mengmeng-chen-2b22a0161',
#  'yili-cse-ucsd',
#  'weiranxiong',
#  'heather-limj',
#  'yayi-guo-76a463123',
#  'jiageng-zhang',
#  'xuzhaoqing',
#  'hang-zhang-189579178',
#  'yucheng-bian-24151614b',
#  'jinmouli',
#  'yuepeng-shen-8b1743193',
#  'darryl-hua',
#  'haomin-wang-a67a7ab5',
#  'chunyi-tu',
#  'yiwen-li-47a019119',
#  'binglin-zhao-lynn',
#  'raissa-antoinette-a87731158',
#  'sw-si-wu',
#  'chenghao-tsai-46678a141',
#  'bo-chen-422836153',
#  'joshua-comes',
#  'lixiang-ao-87140051',
#  'safa-raffo',
#  'russellxie7',
#  'maniknarang',
#  'dian-yu-623226139',
#  'joe-yuxiao-zhou-49579a96',
#  'ygarde',
#  'bettyzhou0915',
#  'zhongzhi-li-403a26b0',
#  'chun-jhen-lai-03196b173',
#  'fanhillary',
#  'tianyinxu',
#  'jiaxuan-ren-7b3a41171',
#  'kimberlycarreon',
#  'zijin-ari-fu-256a42129',
#  'tianyu-sun',
#  'jiawei-zhu',
#  'clarencextan',
#  'ping-tsung-hsu',
#  'alisabeth-rogers',
#  'zhenlin-zhang-780415149',
#  'yuqi-zheng-28bba992',
#  'royalhien',
#  'juiyuchang',
#  'olivia-thai',
#  'yifanxuvanessa',
#  'haoming-zhang-ba3010156',
#  'xianze-meng-190ba2b0',
#  'xuhao-luo-611056162',
#  'jinhao-tang-26276a144',
#  'yujie-zhou-01616',
#  'jacelu0830',
#  'alan-kuo',
#  'weiweixiong',
#  'yu-xia-84769959',
#  'enhaocui',
#  'ting-yu-tiffany-chang-2527a4137',
#  'xingyu-gu',
#  'daletubat',
#  'zack-whz98',
#  'xinyuxie113',
#  'anxunwei',
#  'jonathanshamblen',
#  'james-christian-rich',
#  'lucas-nathan-982801159',
#  'michaelbaqadira',
#  'jianhui-wang-609287172',
#  'tianyi-lu-a34077191',
#  'harshp8l',
#  'juliamaemarkel',
#  'wongaimee',
#  'vanessa-chou-390b40a6',
#  'jin-wu',
#  'bodong-zhang-407706117',
#  'ziyi-wang-iris',
#  'yiwen-song-59682916b',
#  'sarthak-kaul-257679154',
#  'michael-hensen-02663b195',
#  'zijie-zhao',
#  'lijinchen',
#  'eric-fakhourian',
#  'mo-zhang-469a465a',
#  'stevengov',
#  'annanishere',
#  'william-jason-burns',
#  'laitn',
#  'mathurmadhav',
#  'penrose-pengluo-wang-56275b150',
#  'qian-zhang-qiz235',
#  'jianlingliu',
#  'catherine-f-xia',
#  'rui--xu',
#  'runyaochen',
#  'rishabh-malhotra-83aaa5130',
#  'siyu-lai-642736137',
#  'alfredwuy',
#  'jamshed-ashurov',
#  'emilyhuongnguyen',
#  'aveek-biswas',
#  'jingwen-yu-932933160',
#  'ashley-jiang-a9983b113',
#  'qianlong-qu-a8877b130',
#  'jiawei-zhou-2400',
#  'josephl310',
#  'yizhiyuan',
#  'teresa198906',
#  'leo-song-720a65103',
#  'mengjin-katherine-zhang-168865178',
#  'calvintjoeng',
#  'zhiqiang-pi',
#  'xinjin1994',
#  'patrick-salmas-58704b159',
#  'xu-li-577050127',
#  'ejung356',
#  'jiaxin-li-658b66a4',
#  'yiyun-shen',
#  'andreikhmel',
#  'zihan-zheng',
#  'n33',
#  'leejamesgh',
#  'renxu-hu',
#  'renjie-yu-00657220',
#  'yue-chen-b41626170',
#  'nick11roberts',
#  'yancen-pan-697b83143',
#  'fredgrier',
#  'evan-j-xue-501360105',
#  'bohuan-yang-6b10a514a',
#  'arvindsaripalli',
#  'dingcheng-hu-483b7a127',
#  'shiman-shannon-he',
#  'siman-wang-964316139',
#  'czhou29',
#  'qinyan-li-06098213b',
#  'r-deng',
#  'rongrong-liu-893526162',
#  'huilai-miao-326755150',
#  'zehao-xu',
#  'waynevnguyen',
#  'chaolicse',
#  'lishane31',
#  'tuoying-chen',
#  'jinzhao-feng-643327154',
#  'jiazhou-gao-8a661b148',
#  'shihao-luo-37a12a153',
#  'vincent8tong',
#  'lingfei-lu-414b54104',
#  'zhongjie-ren-5b2446156',
#  'wenrui-helena-li',
#  'dingmei',
#  'chu-ling-ko',
#  'xinrong-w-213b2711b',
#  'jiyuan-liu-ucsd',
#  'jiaming-zhang-a371a2152',
#  'qiuxin-sheng-206125b3',
#  'panqu',
#  'yuzhuzhang1',
#  'zhiqiang-sun',
#  'qingyu-zhou',
#  'nan-zhou-profile',
#  'yuanxin-li-9601',
#  'yangguang-he-5a7b54192',
#  'matthew-woods-1581718',
#  'fan-jin-248b9b189',
#  'yingwei-li-4b438765',
#  'devwu',
#  'xiqiang-ken-lin-a3a69a109',
#  'chongbinzhang',
#  'qihuan-ling',
#  'khurram-khakoo-76554049',
#  'han-chi',
#  'panthson',
#  'jiayi-wang-8abb2a156',
#  'anirudhperubotla',
#  'shike-zhang-8b270a173',
#  'sunyuzhuo',
#  'zhaochunma',
#  'chen-shijia-52630588',
#  'ysgcs',
#  'qing-zhang-ucsd',
#  'shen-liu-419b64109',
#  'yan-yi-53820311a',
#  'yuchun-jin',
#  'huiyingqu',
#  'mingyao-zheng',
#  'megan-kwok-193560172',
#  'paulo-gonzales',
#  'nikki-l-kuang',
#  'daphne-lyu',
#  'brentonang',
#  'jis',
#  'junchuan-wang-68906b59',
#  'fantasychen',
#  'yueeleng',
#  'ye-huang-3b9326118',
#  'yang-xu-45b910160',
#  'zikun-yang',
#  'zexi-chen-38412a153',
#  'chenweidai',
#  'wentao-guan-6ab9a9122',
#  'changliangcao',
#  'mayu-zhao',
#  'komailrizvi',
#  'zheshanliu',
#  'ariane-tsai',
#  'zhaowei-cai-34991126',
#  'yu-zhong-78963296',
#  'jianxiongji',
#  'linfeng-tony-zheng',
#  'chris-weaver101',
#  'evawyf',
#  'yijun-olivia-he-33136a126']

# %%
pro_list
# Out:
# [{'industryName': 'Internet',
#   'lastName': 'Wu',
#   'locationName': 'La Jolla, California',
#   'student': False,
#   'geoCountryName': 'United States',
#   'geoCountryUrn': 'urn:li:fs_geo:103644278',
#   'geoLocationBackfilled': True,
#   'elt': False,
#   'industryUrn': 'urn:li:fs_industry:6',
#   'firstName': 'Haofan',
#   'entityUrn': 'urn:li:fs_profile:ACoAACHTROoBkopLJ2EFD55a9uj87BFCqnhZvBA',
#   'geoLocation': {'geoUrn': 'urn:li:fs_geo:100737633'},
#   'geoLocationName': 'San Diego County, California',
#   'location': {'preferredGeoPlace': 'urn:li:fs_city:(us,7-1-0-37-24)',
#    'basicLocation': {'countryCode': 'us'}},
#   'headline': 'SDE I at Amazon',
#   'displayPictureUrl': 'https://media.licdn.com/dms/image/C4D03AQFmoK5CDk6IcQ/profile-displayphoto-shrink_',
#   'profile_id': 'ACoAACHTROoBkopLJ2EFD55a9uj87BFCqnhZvBA',
#   'experience': [{'locationName': 'Greater Seattle Area',
#     'entityUrn': 'urn:li:fs_position:(ACoAACHTROoBkopLJ2EFD55a9uj87BFCqnhZvBA,1469151366)',
#     'geoLocationName': 'Greater Seattle Area',
#     'geoUrn': 'urn:li:fs_geo:90000091',
#     'companyName': 'Amazon',
#     'timePeriod': {'startDate': {'month': 6, 'year': 2019}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Internet']},
#     'title': 'SDE I',
#     'region': 'urn:li:fs_region:(us,91)',
#     'companyUrn': 'urn:li:fs_miniCompany:1586',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C560BAQFdwVGpSOHmgw/company-logo_'},
#    {'entityUrn': 'urn:li:fs_position:(ACoAACHTROoBkopLJ2EFD55a9uj87BFCqnhZvBA,1336678066)',
#     'companyName': 'Morgan Stanley',
#     'timePeriod': {'endDate': {'month': 9, 'year': 2018},
#      'startDate': {'month': 7, 'year': 2018}},
#     'description': 'Working in Commodities Team, technology stack includes Java, Typescript, Sybase, Angular 6, Spring, Apache CXF, Git',
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Financial Services']},
#     'title': 'Software Development Intern',
#     'companyUrn': 'urn:li:fs_miniCompany:497017',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C510BAQFio6MUF0Ss_A/company-logo_'}],
#   'skills': [{'name': 'Java',
#     'standardizedSkillUrn': 'urn:li:fs_miniSkill:147',
#     'standardizedSkill': {'name': 'Java',
#      'entityUrn': 'urn:li:fs_miniSkill:147'}},
#    {'name': 'Python'},
#    {'name': 'JavaScript'},
#    {'name': 'CSS'},
#    {'name': 'HTML5'},
#    {'name': 'MySQL'},
#    {'name': 'Machine Learning'},
#    {'name': 'jQuery'},
#    {'name': 'Bootstrap'},
#    {'name': 'Group Work'},
#    {'name': 'Machine Vision'},
#    {'name': 'Team Leadership'},
#    {'name': 'Debate'},
#    {'name': 'Matlab',
#     'standardizedSkillUrn': 'urn:li:fs_miniSkill:1442',
#     'standardizedSkill': {'name': 'Matlab',
#      'entityUrn': 'urn:li:fs_miniSkill:1442'}},
#    {'name': 'PHP'},
#    {'name': 'Software Design'},
#    {'name': 'C++'},
#    {'name': 'Spring Framework'},
#    {'name': 'SQL'},
#    {'name': 'Git'},
#    {'name': 'Scalability'},
#    {'name': 'Writing'},
#    {'name': 'LinkedIn'}],
#   'education': [{'courses': ['urn:li:fs_course:(ACoAACHTROoBkopLJ2EFD55a9uj87BFCqnhZvBA,809751232)',
#      'urn:li:fs_course:(ACoAACHTROoBkopLJ2EFD55a9uj87BFCqnhZvBA,809770856)',
#      'urn:li:fs_course:(ACoAACHTROoBkopLJ2EFD55a9uj87BFCqnhZvBA,809824732)',
#      'urn:li:fs_course:(ACoAACHTROoBkopLJ2EFD55a9uj87BFCqnhZvBA,809847477)',
#      'urn:li:fs_course:(ACoAACHTROoBkopLJ2EFD55a9uj87BFCqnhZvBA,809866457)',
#      'urn:li:fs_course:(ACoAACHTROoBkopLJ2EFD55a9uj87BFCqnhZvBA,809886744)'],
#     'projects': ['urn:li:fs_project:(ACoAACHTROoBkopLJ2EFD55a9uj87BFCqnhZvBA,809502430)',
#      'urn:li:fs_project:(ACoAACHTROoBkopLJ2EFD55a9uj87BFCqnhZvBA,1785313539)',
#      'urn:li:fs_project:(ACoAACHTROoBkopLJ2EFD55a9uj87BFCqnhZvBA,1785457123)'],
#     'entityUrn': 'urn:li:fs_education:(ACoAACHTROoBkopLJ2EFD55a9uj87BFCqnhZvBA,460633851)',
#     'school': {'objectUrn': 'urn:li:school:17954',
#      'entityUrn': 'urn:li:fs_miniSchool:17954',
#      'active': True,
#      'schoolName': 'University of California San Diego',
#      'trackingId': 'GsBDHnQvQc+zIrY28QHziA==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C560BAQHQYa-3EY_aaQ/company-logo_'},
#     'timePeriod': {'endDate': {'year': 2019}, 'startDate': {'year': 2017}},
#     'degreeName': "Master's degree",
#     'schoolName': 'University of California San Diego',
#     'fieldOfStudy': 'computer science',
#     'degreeUrn': 'urn:li:fs_degree:500',
#     'schoolUrn': 'urn:li:fs_miniSchool:17954'},
#    {'entityUrn': 'urn:li:fs_education:(ACoAACHTROoBkopLJ2EFD55a9uj87BFCqnhZvBA,397040733)',
#     'school': {'objectUrn': 'urn:li:school:11253',
#      'entityUrn': 'urn:li:fs_miniSchool:11253',
#      'active': True,
#      'schoolName': 'Nanjing University',
#      'trackingId': 'NhxGxR5ORq+aB2GYzz2l9w==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C4D0BAQGsoyqBOckyJQ/company-logo_'},
#     'activities': '2016 Mathematical Contest in Modeling – Meritorious Winner (Group Leader); 2015 National Undergraduate Electronic Design Contest – National Second Prize (Teamwork); 2015 TEXAS INSTRUMENTS CUP – Provincial First Prize Sponsored by Texas Instruments.',
#     'grade': '3.8/4.0(WES)',
#     'timePeriod': {'endDate': {'year': 2017}, 'startDate': {'year': 2013}},
#     'degreeName': 'Bachelor of Science - BS',
#     'schoolName': 'Nanjing University',
#     'fieldOfStudy': 'Electronic Information Science and Technology',
#     'degreeUrn': 'urn:li:fs_degree:400',
#     'schoolUrn': 'urn:li:fs_miniSchool:11253'}]},
#  {'summary': "Master Student studying analytics at University of Southern California.\nWeb Developer with a demonstrated history of working in the non-profit organization management industry. Data Structure, Algorithm, Java, and Python. Strong engineering professional with a Bachelor's degree focused in Mathematics and Computer Science from University of California San Diego.\nFeel free to contact me via email and add me to your network.",
#   'industryName': 'Computer Software',
#   'lastName': 'GUANYU',
#   'locationName': 'Los Angeles, California',
#   'student': False,
#   'geoCountryName': 'United States',
#   'geoCountryUrn': 'urn:li:fs_geo:103644278',
#   'geoLocationBackfilled': True,
#   'elt': False,
#   'industryUrn': 'urn:li:fs_industry:4',
#   'firstName': 'CHEN',
#   'entityUrn': 'urn:li:fs_profile:ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0',
#   'geoLocation': {'geoUrn': 'urn:li:fs_geo:102448103'},
#   'geoLocationName': 'Los Angeles, California',
#   'location': {'preferredGeoPlace': 'urn:li:fs_city:(us,7-1-0-19-57)',
#    'basicLocation': {'countryCode': 'us'}},
#   'headline': 'Graduate Student of Analytics at University of Southern California',
#   'displayPictureUrl': 'https://media.licdn.com/dms/image/C5603AQF8kKf-ox3Y0Q/profile-displayphoto-shrink_',
#   'profile_id': 'ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0',
#   'experience': [{'locationName': 'Greater San Diego Area',
#     'entityUrn': 'urn:li:fs_position:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,1509085097)',
#     'geoLocationName': 'Greater San Diego Area',
#     'geoUrn': 'urn:li:fs_geo:100737633',
#     'companyName': 'InMotion USA',
#     'timePeriod': {'endDate': {'month': 8, 'year': 2019},
#      'startDate': {'month': 4, 'year': 2019}},
#     'description': "▪ Developed website based on the concept of sharing owners' devices in leisure time to earn revenue and provide a new method of traveling in the city\n▪ Used Express framwork and Node.js to test and develop the Javascript and CSS code\n▪ Chose MongoDB as the database and used multiple schema to define the attributes of devices\n▪ Enabled detailed search by going through database to pull out the specified results, like speed, range, model type",
#     'company': {'employeeCountRange': {'start': 2, 'end': 10},
#      'industries': ['Electrical/Electronic Manufacturing']},
#     'title': 'Web Developer Internship',
#     'region': 'urn:li:fs_region:(us,732)',
#     'companyUrn': 'urn:li:fs_miniCompany:18313826',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C560BAQFBZTVr3wyQLw/company-logo_'},
#    {'locationName': 'Greater San Diego Area',
#     'entityUrn': 'urn:li:fs_position:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,1453387229)',
#     'geoLocationName': 'Greater San Diego Area',
#     'companyName': 'UCSD Chinese Computer Community',
#     'timePeriod': {'endDate': {'month': 7, 'year': 2019},
#      'startDate': {'month': 4, 'year': 2019}},
#     'description': '▪ Developed new features for Triple C official website (sponsor page, administrator login page)\n▪ Fixed navigation bar on top of the web page to enable a better user experience on searching different sections\n▪ Website maintenance and bug fix\n▪ Update the information on the website to the latest version\n▪ Turn the website into a full-stack web app which can store the contact information made on the website by linking the backend with MySQL and Java\n▪ Presenter of the official website on demo day to show the progress made in a whole quarter to over 100 audiences',
#     'company': {'employeeCountRange': {'start': 51, 'end': 200},
#      'industries': ['Nonprofit Organization Management']},
#     'title': 'Full Stack Developer',
#     'companyUrn': 'urn:li:fs_miniCompany:18601343',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C560BAQESuxCqIZANnw/company-logo_'},
#    {'locationName': 'La Jolla, San Diego',
#     'entityUrn': 'urn:li:fs_position:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,1387243782)',
#     'geoLocationName': 'La Jolla, San Diego',
#     'companyName': "John's Market at UCSD",
#     'timePeriod': {'endDate': {'month': 6, 'year': 2017},
#      'startDate': {'month': 3, 'year': 2017}},
#     'description': '▪ Cashier at the front desk: scan goods for customers. \n▪ Server in the front: make coffees and different drinks for customers. \n▪ Stocking jobs in the back, refill merchandises on the shelf, clean the floor and front desk and take care \n  of waste accordingly to recyclable or unrecyclable. \n▪ Good teamwork with coworkers.',
#     'title': 'Cashier'}],
#   'skills': [{'name': 'Java'},
#    {'name': 'HTML5'},
#    {'name': 'Python (Programming Language)'},
#    {'name': 'Research',
#     'standardizedSkillUrn': 'urn:li:fs_miniSkill:176',
#     'standardizedSkill': {'name': 'Research',
#      'entityUrn': 'urn:li:fs_miniSkill:176'}},
#    {'name': 'Data Structures'},
#    {'name': 'C++'},
#    {'name': 'C (Programming Language)'},
#    {'name': 'Microsoft Word'},
#    {'name': 'Microsoft Excel'},
#    {'name': 'Microsoft PowerPoint'},
#    {'name': 'Microsoft Office'},
#    {'name': 'Cascading Style Sheets (CSS)'},
#    {'name': 'JavaScript'},
#    {'name': 'jQuery'},
#    {'name': 'Node.js'},
#    {'name': 'Embedded JavaScript (EJS)'},
#    {'name': 'OpenGL'},
#    {'name': 'Semantic UI'},
#    {'name': 'MongoDB'},
#    {'name': 'Customer Service'},
#    {'name': 'Teamwork',
#     'standardizedSkillUrn': 'urn:li:fs_miniSkill:921',
#     'standardizedSkill': {'name': 'Teamwork',
#      'entityUrn': 'urn:li:fs_miniSkill:921'}},
#    {'name': 'English',
#     'standardizedSkillUrn': 'urn:li:fs_miniSkill:274',
#     'standardizedSkill': {'name': 'English',
#      'entityUrn': 'urn:li:fs_miniSkill:274'}},
#    {'name': 'Chinese'},
#    {'name': 'Japanese'},
#    {'name': 'SystemVerilog'},
#    {'name': 'HTML'},
#    {'name': 'MySQL'},
#    {'name': 'SQL'}],
#   'education': [{'entityUrn': 'urn:li:fs_education:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,596463514)',
#     'school': {'objectUrn': 'urn:li:school:17971',
#      'entityUrn': 'urn:li:fs_miniSchool:17971',
#      'active': True,
#      'schoolName': 'University of Southern California',
#      'trackingId': 'ezprDQvtRYiHWNzz00r1KQ==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C4E0BAQHatTfEv4Af6w/company-logo_'},
#     'timePeriod': {'endDate': {'year': 2021}, 'startDate': {'year': 2019}},
#     'degreeName': 'Master of Science - MS',
#     'schoolName': 'University of Southern California',
#     'fieldOfStudy': 'Analytics',
#     'degreeUrn': 'urn:li:fs_degree:626',
#     'schoolUrn': 'urn:li:fs_miniSchool:17971'},
#    {'courses': ['urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,592181817)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,592251426)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,592293303)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,592359327)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,592386990)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,592423566)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,592472269)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,592520603)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,592614350)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,938029386)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,938059650)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,999094780)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,999147274)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,999164008)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,999209017)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,999241689)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,999291979)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,1116826613)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,1116867810)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,1116914062)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,1116945337)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,1116994442)',
#      'urn:li:fs_course:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,1117090702)'],
#     'projects': ['urn:li:fs_project:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,894477721)'],
#     'entityUrn': 'urn:li:fs_education:(ACoAAB2aVKgBh0KOlprYHb_3ZbOFvisbhm3etu0,503410233)',
#     'school': {'objectUrn': 'urn:li:school:17954',
#      'entityUrn': 'urn:li:fs_miniSchool:17954',
#      'active': True,
#      'schoolName': 'University of California San Diego',
#      'trackingId': 'qj80zQOsTnW/J1cV8ELTJw==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C560BAQHQYa-3EY_aaQ/company-logo_'},
#     'grade': '3.4',
#     'timePeriod': {'endDate': {'year': 2019}, 'startDate': {'year': 2015}},
#     'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100761',
#     'degreeName': "Bachelor's degree",
#     'schoolName': 'University of California San Diego',
#     'fieldOfStudy': 'Mathematics and Computer Science',
#     'degreeUrn': 'urn:li:fs_degree:200',
#     'schoolUrn': 'urn:li:fs_miniSchool:17954'}]},
#  {'industryName': 'Computer Software',
#   'lastName': 'Shen',
#   'locationName': 'San Diego, California',
#   'student': False,
#   'geoCountryName': 'United States',
#   'geoCountryUrn': 'urn:li:fs_geo:103644278',
#   'geoLocationBackfilled': True,
#   'elt': False,
#   'industryUrn': 'urn:li:fs_industry:4',
#   'firstName': 'Yujing',
#   'entityUrn': 'urn:li:fs_profile:ACoAACUlT20B_XQEA_mPUri4BnsqwQzME2YfHQ0',
#   'geoLocation': {'geoUrn': 'urn:li:fs_geo:103918656'},
#   'geoLocationName': 'San Diego, California',
#   'location': {'preferredGeoPlace': 'urn:li:fs_city:(us,7-1-0-37-41)',
#    'basicLocation': {'countryCode': 'us'}},
#   'headline': 'Student at University of California San Diego',
#   'displayPictureUrl': 'https://media.licdn.com/dms/image/C5603AQF4gVXfq-Drxw/profile-displayphoto-shrink_',
#   'profile_id': 'ACoAACUlT20B_XQEA_mPUri4BnsqwQzME2YfHQ0',
#   'experience': [{'locationName': 'Shanghai City, China',
#     'entityUrn': 'urn:li:fs_position:(ACoAACUlT20B_XQEA_mPUri4BnsqwQzME2YfHQ0,1460488961)',
#     'geoLocationName': 'Shanghai City, China',
#     'geoUrn': 'urn:li:fs_geo:102772228',
#     'companyName': 'Google',
#     'timePeriod': {'endDate': {'month': 8, 'year': 2019},
#      'startDate': {'month': 5, 'year': 2019}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Internet']},
#     'title': 'Software Engineer Intern in Machine Learning',
#     'region': 'urn:li:fs_region:(cn,8909)',
#     'companyUrn': 'urn:li:fs_miniCompany:1441',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C4D0BAQHiNSL4Or29cg/company-logo_'},
#    {'locationName': 'Beijing City, China',
#     'entityUrn': 'urn:li:fs_position:(ACoAACUlT20B_XQEA_mPUri4BnsqwQzME2YfHQ0,1389659336)',
#     'geoLocationName': 'Beijing City, China',
#     'geoUrn': 'urn:li:fs_geo:103873152',
#     'companyName': 'SenseTime 商汤科技',
#     'timePeriod': {'endDate': {'month': 4, 'year': 2019},
#      'startDate': {'month': 12, 'year': 2018}},
#     'company': {'employeeCountRange': {'start': 1001, 'end': 5000},
#      'industries': ['Computer Software']},
#     'title': 'Research Intern',
#     'region': 'urn:li:fs_region:(cn,8911)',
#     'companyUrn': 'urn:li:fs_miniCompany:9272195',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C560BAQEVqUsQIAdXQw/company-logo_'},
#    {'locationName': 'Shanghai City, China',
#     'entityUrn': 'urn:li:fs_position:(ACoAACUlT20B_XQEA_mPUri4BnsqwQzME2YfHQ0,1334302056)',
#     'geoLocationName': 'Shanghai City, China',
#     'geoUrn': 'urn:li:fs_geo:102772228',
#     'companyName': 'Google',
#     'timePeriod': {'endDate': {'month': 9, 'year': 2018},
#      'startDate': {'month': 7, 'year': 2018}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Internet']},
#     'title': 'Software Engineer Intern',
#     'region': 'urn:li:fs_region:(cn,8909)',
#     'companyUrn': 'urn:li:fs_miniCompany:1441',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C4D0BAQHiNSL4Or29cg/company-logo_'}],
#   'skills': [{'name': 'C++'}, {'name': 'Python'}],
#   'education': [{'entityUrn': 'urn:li:fs_education:(ACoAACUlT20B_XQEA_mPUri4BnsqwQzME2YfHQ0,611812992)',
#     'school': {'objectUrn': 'urn:li:school:17954',
#      'entityUrn': 'urn:li:fs_miniSchool:17954',
#      'active': True,
#      'schoolName': 'University of California San Diego',
#      'trackingId': '8Pr1z5H3TK6WPByXqRsYZQ==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C560BAQHQYa-3EY_aaQ/company-logo_'},
#     'timePeriod': {'endDate': {'year': 2021}, 'startDate': {'year': 2019}},
#     'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100189',
#     'degreeName': "Master's degree",
#     'schoolName': 'University of California San Diego',
#     'fieldOfStudy': 'Computer Science',
#     'degreeUrn': 'urn:li:fs_degree:500',
#     'schoolUrn': 'urn:li:fs_miniSchool:17954'},
#    {'entityUrn': 'urn:li:fs_education:(ACoAACUlT20B_XQEA_mPUri4BnsqwQzME2YfHQ0,473566260)',
#     'school': {'objectUrn': 'urn:li:school:11319',
#      'entityUrn': 'urn:li:fs_miniSchool:11319',
#      'active': True,
#      'schoolName': 'Shanghai Jiao Tong University',
#      'trackingId': 'aSJXTvQdT/SODhlRMwJEDw==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C4E0BAQFkNUM4pr0xcg/company-logo_'},
#     'timePeriod': {'endDate': {'year': 2019}, 'startDate': {'year': 2015}},
#     'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100189',
#     'degreeName': "Bachelor's degree",
#     'schoolName': 'Shanghai Jiao Tong University',
#     'fieldOfStudy': 'Computer Science',
#     'degreeUrn': 'urn:li:fs_degree:200',
#     'schoolUrn': 'urn:li:fs_miniSchool:11319'}]},
#  {'summary': 'I am a Deep Learning Engineer, experienced in working on image- and vision-based tasks, but with interest in a lot of other technologies, such as Reinforcement Learning and Generative Models.',
#   'industryName': 'Computer Software',
#   'lastName': 'George',
#   'locationName': 'United States',
#   'student': False,
#   'geoCountryName': 'United States',
#   'geoCountryUrn': 'urn:li:fs_geo:103644278',
#   'geoLocationBackfilled': True,
#   'elt': False,
#   'industryUrn': 'urn:li:fs_industry:4',
#   'firstName': 'Melvin',
#   'entityUrn': 'urn:li:fs_profile:ACoAACoP8AsBLbLdyNBDGapK3phC7RhgvEG_7Ng',
#   'geoLocation': {'geoUrn': 'urn:li:fs_geo:90000084'},
#   'geoLocationName': 'San Francisco Bay Area',
#   'location': {'basicLocation': {'countryCode': 'us'}},
#   'headline': 'Student at University of California San Diego',
#   'displayPictureUrl': 'https://media.licdn.com/dms/image/C4E03AQFzk8AMVWP58Q/profile-displayphoto-shrink_',
#   'profile_id': 'ACoAACoP8AsBLbLdyNBDGapK3phC7RhgvEG_7Ng',
#   'experience': [{'locationName': 'Berkeley, CA',
#     'entityUrn': 'urn:li:fs_position:(ACoAACoP8AsBLbLdyNBDGapK3phC7RhgvEG_7Ng,1480217727)',
#     'geoLocationName': 'Berkeley, CA',
#     'companyName': 'University of California, Berkeley',
#     'timePeriod': {'endDate': {'month': 11, 'year': 2018},
#      'startDate': {'month': 11, 'year': 2018}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Higher Education']},
#     'title': 'Machine Learning Mentor, Cal Hacks',
#     'companyUrn': 'urn:li:fs_miniCompany:2517',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C560BAQHylmb-tm1JOw/company-logo_'}],
#   'skills': [{'name': 'Machine Learning'},
#    {'name': 'Software Development'},
#    {'name': 'Probability'},
#    {'name': 'Data Mining'},
#    {'name': 'Statistics'},
#    {'name': 'Data Science'},
#    {'name': 'Data Analysis'},
#    {'name': 'Operating Systems'},
#    {'name': 'Python (Programming Language)'},
#    {'name': 'PyTorch'},
#    {'name': 'C++'},
#    {'name': 'Java'},
#    {'name': 'Oracle SQL Developer'},
#    {'name': 'TensorFlow'},
#    {'name': 'Amazon Web Services (AWS)'}],
#   'education': [{'entityUrn': 'urn:li:fs_education:(ACoAACoP8AsBLbLdyNBDGapK3phC7RhgvEG_7Ng,599079958)',
#     'school': {'objectUrn': 'urn:li:school:17959',
#      'entityUrn': 'urn:li:fs_miniSchool:17959',
#      'active': True,
#      'schoolName': 'UC Santa Barbara',
#      'trackingId': 'YpzQhFRmRWmFdS6xs/NVoQ==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C510BAQHEZRcLGw73jQ/company-logo_'},
#     'timePeriod': {'endDate': {'year': 2020}, 'startDate': {'year': 2018}},
#     'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100189',
#     'degreeName': "Bachelor's degree",
#     'schoolName': 'UC Santa Barbara',
#     'fieldOfStudy': 'Computer Science',
#     'degreeUrn': 'urn:li:fs_degree:200',
#     'schoolUrn': 'urn:li:fs_miniSchool:17959'},
#    {'entityUrn': 'urn:li:fs_education:(ACoAACoP8AsBLbLdyNBDGapK3phC7RhgvEG_7Ng,570688995)',
#     'school': {'objectUrn': 'urn:li:school:17954',
#      'entityUrn': 'urn:li:fs_miniSchool:17954',
#      'active': True,
#      'schoolName': 'University of California San Diego',
#      'trackingId': 'HOkh+laSQ/S6/ywot2+blg==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C560BAQHQYa-3EY_aaQ/company-logo_'},
#     'grade': '3.74',
#     'timePeriod': {'endDate': {'year': 2017}, 'startDate': {'year': 2016}},
#     'description': 'Courses: \nCSE 100 (Advanced Data Structure)\nCSE 101 (Design & Analysis of Algorithms)\nCSE 103 (Practical Intro to Probability & Statistics)\nCSE 105 (Intro to Theory of Computation)\nCSE 107 (Modern Cryptography)\nCSE 110 (Software Engineering)\n',
#     'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100189',
#     'degreeName': 'Bachelor of Science - BS',
#     'schoolName': 'University of California San Diego',
#     'fieldOfStudy': 'Computer Science',
#     'degreeUrn': 'urn:li:fs_degree:400',
#     'schoolUrn': 'urn:li:fs_miniSchool:17954'}]},
#  {'summary': 'Experienced Academic with a demonstrated history of working in the higher education industry. Skilled in a programming language like Python, Java, C++, Matlab and applications like EEGLAB, AWS. Strong education professional with a Bachelor of Science - BS focused on Computer Science and Mathematics from the University of California, San Diego.',
#   'industryName': 'Information Technology & Services',
#   'lastName': 'Dai',
#   'locationName': 'United States',
#   'student': False,
#   'geoCountryName': 'United States',
#   'geoCountryUrn': 'urn:li:fs_geo:103644278',
#   'geoLocationBackfilled': True,
#   'elt': False,
#   'industryUrn': 'urn:li:fs_industry:96',
#   'firstName': 'David',
#   'entityUrn': 'urn:li:fs_profile:ACoAAAxWe_cBE65ahpioQHQ99_Huqk73VUfcjWY',
#   'geoLocation': {'geoUrn': 'urn:li:fs_geo:100737633'},
#   'geoLocationName': 'San Diego County, California',
#   'location': {'basicLocation': {'countryCode': 'us'}},
#   'headline': 'RA @ SCCN',
#   'displayPictureUrl': 'https://media.licdn.com/dms/image/C5603AQEQ7vcwI-A_hQ/profile-displayphoto-shrink_',
#   'profile_id': 'ACoAAAxWe_cBE65ahpioQHQ99_Huqk73VUfcjWY',
#   'experience': [{'locationName': 'San Diego',
#     'entityUrn': 'urn:li:fs_position:(ACoAAAxWe_cBE65ahpioQHQ99_Huqk73VUfcjWY,1437883206)',
#     'geoLocationName': 'San Diego',
#     'companyName': 'San Diego Supercomputer Center',
#     'timePeriod': {'startDate': {'month': 1, 'year': 2019}},
#     'description': 'o\tResearching under Tzyy-Ping Jung at the Swartz Center of Computational Neuroscience \no\tEnhancing multivariate weighted recurrence networks (MWRN) in PyTorch to improve deep learning emotion classification accuracy for multi-mode electroencephalogram (EEG) data\no\tDeveloping a more efficient signal pre-processing of the EEG data in Matlab for EEGLAB extension\no\tEstablishing a conventional data processing method disregarding the number of EEG channels',
#     'company': {'employeeCountRange': {'start': 201, 'end': 500},
#      'industries': ['Information Technology and Services']},
#     'title': 'Research Assistant',
#     'companyUrn': 'urn:li:fs_miniCompany:10843',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C560BAQELHgCB8o5tSA/company-logo_'},
#    {'entityUrn': 'urn:li:fs_position:(ACoAAAxWe_cBE65ahpioQHQ99_Huqk73VUfcjWY,1476718450)',
#     'companyName': 'GE Transportation',
#     'timePeriod': {'endDate': {'month': 8, 'year': 2019},
#      'startDate': {'month': 6, 'year': 2019}},
#     'description': 'o\tBuilding a Chabot with AWS Lex and Lambda for users to skip the customer service queue and direct manipulate eServices; thus, saving estimate two million dollars annually on customer service\no\tExperimenting with the Data Analytics team to establish an intent-classification-based Chabot proof of concept (POC) using RASA and Seq-2-Seq deep learning model\no\tImplementing the user interface (UI) with different python GUI packages Django, tkinter, and kivy for the 3-tier architecture Chatbot POC\no\tCreating a platform for GE LEAD program hires to select tracks and programs for rotation with Angular, Spring Framework and MySQL and thus, cutting selection process spending by 50%',
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Transportation/Trucking/Railroad']},
#     'title': 'LEAD IT Intern',
#     'companyUrn': 'urn:li:fs_miniCompany:8127',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C4E0BAQHiuXMRobMprQ/company-logo_'},
#    {'locationName': 'Greater San Diego Area',
#     'entityUrn': 'urn:li:fs_position:(ACoAAAxWe_cBE65ahpioQHQ99_Huqk73VUfcjWY,1097844090)',
#     'geoLocationName': 'Greater San Diego Area',
#     'companyName': 'University of California San Diego',
#     'timePeriod': {'endDate': {'month': 6, 'year': 2019},
#      'startDate': {'month': 10, 'year': 2017}},
#     'description': 'o\tHosted office and lab, grading homework and facilitating in-class discussion for 164 students\no\tPromoted the culture of Academic Integrity on the UCSD campus and practicing confidentiality\no\tTutored design techniques for digital systems and algorithm design for UCSD undergraduates',
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Higher Education']},
#     'title': 'Tutor',
#     'companyUrn': 'urn:li:fs_miniCompany:3382',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C560BAQHQYa-3EY_aaQ/company-logo_'},
#    {'locationName': 'University of California, San Diego',
#     'entityUrn': 'urn:li:fs_position:(ACoAAAxWe_cBE65ahpioQHQ99_Huqk73VUfcjWY,1295488655)',
#     'geoLocationName': 'University of California, San Diego',
#     'companyName': 'Triton Rocket Club at UCSD',
#     'timePeriod': {'endDate': {'month': 3, 'year': 2019},
#      'startDate': {'month': 4, 'year': 2018}},
#     'description': 'o\tExecutive member of the club\no\tTaking responsibility to manage the TRC on-campus and off-campus\no\tProviding secure funding for club development and funding fluidity',
#     'company': {},
#     'title': 'Treasurer',
#     'companyUrn': 'urn:li:fs_miniCompany:18048133',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C4D0BAQE4kmo1xIBHbg/company-logo_'},
#    {'entityUrn': 'urn:li:fs_position:(ACoAAAxWe_cBE65ahpioQHQ99_Huqk73VUfcjWY,1374407015)',
#     'companyName': 'San Diego Robotics 101',
#     'timePeriod': {'endDate': {'month': 1, 'year': 2019},
#      'startDate': {'month': 5, 'year': 2018}},
#     'description': 'o\tUtilized Python, ARM, and C++ to build a submarine to complete automated rescue missions\no\tRanked 8th place out of 47 participants in the U.S. Navy RoboSub competition\no\tProgrammed the Raspberry Pi2 brain (center control system) for the robot: receiving data from the motors, IMU, sonar sensor, camera and so forth and process the data to manipulate the submarine',
#     'company': {'employeeCountRange': {'start': 2, 'end': 10},
#      'industries': ['Computer Software']},
#     'title': 'Programmer',
#     'companyUrn': 'urn:li:fs_miniCompany:35589810',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C4E0BAQFMhY9E4tzxEQ/company-logo_'}],
#   'skills': [{'name': 'Java'},
#    {'name': 'C++'},
#    {'name': 'Python'},
#    {'name': 'Numerical Analysis'},
#    {'name': 'Photography'},
#    {'name': 'Translation'},
#    {'name': 'ARM'},
#    {'name': 'Data Analysis'},
#    {'name': 'C'},
#    {'name': 'UNIX'},
#    {'name': 'Matlab'},
#    {'name': 'MySQL'},
#    {'name': 'Arduino'},
#    {'name': 'Chinese'},
#    {'name': 'SPARC'},
#    {'name': 'Robotc'}],
#   'education': [{'entityUrn': 'urn:li:fs_education:(ACoAAAxWe_cBE65ahpioQHQ99_Huqk73VUfcjWY,353225086)',
#     'school': {'objectUrn': 'urn:li:school:17954',
#      'entityUrn': 'urn:li:fs_miniSchool:17954',
#      'active': True,
#      'schoolName': 'University of California San Diego',
#      'trackingId': 'GikmBs8DT+Om27bbVRHl9Q==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C560BAQHQYa-3EY_aaQ/company-logo_'},
#     'timePeriod': {'endDate': {'year': 2020}, 'startDate': {'year': 2016}},
#     'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100761',
#     'degreeName': 'Bachelor of Science - BS',
#     'schoolName': 'University of California, San Diego',
#     'fieldOfStudy': 'Mathematics and Computer Science',
#     'degreeUrn': 'urn:li:fs_degree:400',
#     'schoolUrn': 'urn:li:fs_miniSchool:17954'},
#    {'entityUrn': 'urn:li:fs_education:(ACoAAAxWe_cBE65ahpioQHQ99_Huqk73VUfcjWY,309618155)',
#     'activities': 'Orchestra; Robotics; Science Olympiad; Tennis; Basketball; Ultimate Frisbee',
#     'grade': 'A/A-',
#     'timePeriod': {'endDate': {'year': 2016}, 'startDate': {'year': 2012}},
#     'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:101500',
#     'degreeName': 'High School Diploma',
#     'schoolName': 'La Jolla Country Day School',
#     'fieldOfStudy': 'High School/Secondary Diplomas and Certificates'}]},
#  {'industryName': 'Computer Software',
#   'lastName': 'zhou',
#   'locationName': 'San Diego, California',
#   'student': False,
#   'geoCountryName': 'United States',
#   'geoCountryUrn': 'urn:li:fs_geo:103644278',
#   'geoLocationBackfilled': True,
#   'elt': False,
#   'industryUrn': 'urn:li:fs_industry:4',
#   'firstName': 'qisen',
#   'entityUrn': 'urn:li:fs_profile:ACoAABjdcuQBA7y0TXDys3gcfVPB_CzFdkyRokw',
#   'geoLocation': {'geoUrn': 'urn:li:fs_geo:103918656'},
#   'geoLocationName': 'San Diego, California',
#   'location': {'preferredGeoPlace': 'urn:li:fs_city:(us,7-1-0-37-41)',
#    'basicLocation': {'countryCode': 'us'}},
#   'headline': 'seeking a software engineer internship',
#   'displayPictureUrl': 'https://media.licdn.com/dms/image/C5603AQFAcKfN43Bwxg/profile-displayphoto-shrink_',
#   'profile_id': 'ACoAABjdcuQBA7y0TXDys3gcfVPB_CzFdkyRokw',
#   'experience': [{'locationName': 'Greater San Diego Area',
#     'entityUrn': 'urn:li:fs_position:(ACoAABjdcuQBA7y0TXDys3gcfVPB_CzFdkyRokw,1101658377)',
#     'geoLocationName': 'Greater San Diego Area',
#     'geoUrn': 'urn:li:fs_geo:100737633',
#     'companyName': 'group project',
#     'timePeriod': {'endDate': {'month': 10, 'year': 2017},
#      'startDate': {'month': 9, 'year': 2017}},
#     'description': 'Titan is a restaurant search and recommendation app + service to improve personal experience for restaurant seekers.\nThe front-end includes a HTML page to interact with user.\nThe backend includes a database and a java service to process data.',
#     'title': 'Titan App',
#     'region': 'urn:li:fs_region:(us,732)'},
#    {'locationName': 'Greater San Diego Area',
#     'entityUrn': 'urn:li:fs_position:(ACoAABjdcuQBA7y0TXDys3gcfVPB_CzFdkyRokw,1115346083)',
#     'geoLocationName': 'Greater San Diego Area',
#     'geoUrn': 'urn:li:fs_geo:100737633',
#     'companyName': 'UCSD Chinese Students and Scholars Association',
#     'timePeriod': {'endDate': {'month': 7, 'year': 2017},
#      'startDate': {'month': 4, 'year': 2016}},
#     'description': 'Worked in out-reaching department and take the responsibility to contact businessman/ businesswomen and convince them to support us with sponsor.\n',
#     'company': {'employeeCountRange': {'start': 51, 'end': 200},
#      'industries': ['Nonprofit Organization Management']},
#     'title': 'OUT-REACHING OFFICER',
#     'region': 'urn:li:fs_region:(us,732)',
#     'companyUrn': 'urn:li:fs_miniCompany:3076220',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C4E0BAQGveFRrDDvqLw/company-logo_'},
#    {'locationName': 'China',
#     'entityUrn': 'urn:li:fs_position:(ACoAABjdcuQBA7y0TXDys3gcfVPB_CzFdkyRokw,856074142)',
#     'geoLocationName': 'China',
#     'geoUrn': 'urn:li:fs_geo:102890883',
#     'companyName': '久远银海软件有限公司',
#     'timePeriod': {'endDate': {'month': 9, 'year': 2016},
#      'startDate': {'month': 8, 'year': 2016}},
#     'title': 'Software engineer',
#     'region': 'urn:li:fs_region:(cn,0)'}],
#   'skills': [{'name': '核心 Java'},
#    {'name': 'Microsoft Office',
#     'standardizedSkillUrn': 'urn:li:fs_miniSkill:366',
#     'standardizedSkill': {'name': 'Microsoft Office',
#      'entityUrn': 'urn:li:fs_miniSkill:366'}},
#    {'name': 'c++'},
#    {'name': 'Microsoft Excel',
#     'standardizedSkillUrn': 'urn:li:fs_miniSkill:163',
#     'standardizedSkill': {'name': 'Microsoft Excel',
#      'entityUrn': 'urn:li:fs_miniSkill:163'}},
#    {'name': 'Leadership',
#     'standardizedSkillUrn': 'urn:li:fs_miniSkill:154',
#     'standardizedSkill': {'name': 'Leadership',
#      'entityUrn': 'urn:li:fs_miniSkill:154'}},
#    {'name': 'Microsoft Word',
#     'standardizedSkillUrn': 'urn:li:fs_miniSkill:260',
#     'standardizedSkill': {'name': 'Microsoft Word',
#      'entityUrn': 'urn:li:fs_miniSkill:260'}},
#    {'name': 'Microsoft PowerPoint',
#     'standardizedSkillUrn': 'urn:li:fs_miniSkill:310',
#     'standardizedSkill': {'name': 'Microsoft PowerPoint',
#      'entityUrn': 'urn:li:fs_miniSkill:310'}},
#    {'name': 'java'},
#    {'name': 'Java 小程序'},
#    {'name': 'Java'}],
#   'education': [{'entityUrn': 'urn:li:fs_education:(ACoAABjdcuQBA7y0TXDys3gcfVPB_CzFdkyRokw,450377242)',
#     'school': {'objectUrn': 'urn:li:school:17954',
#      'entityUrn': 'urn:li:fs_miniSchool:17954',
#      'active': True,
#      'schoolName': 'University of California San Diego',
#      'trackingId': 'mjo0Be4RQsyacKUWO5xrnQ==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C560BAQHQYa-3EY_aaQ/company-logo_'},
#     'timePeriod': {'endDate': {'year': 2018}, 'startDate': {'year': 2015}},
#     'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100761',
#     'degreeName': 'Bachelor of Applied Science - BASc',
#     'schoolName': 'University of California San Diego',
#     'fieldOfStudy': 'Mathematics and Computer Science',
#     'degreeUrn': 'urn:li:fs_degree:259',
#     'schoolUrn': 'urn:li:fs_miniSchool:17954'},
#    {'entityUrn': 'urn:li:fs_education:(ACoAABjdcuQBA7y0TXDys3gcfVPB_CzFdkyRokw,456853450)',
#     'school': {'objectUrn': 'urn:li:school:20987',
#      'entityUrn': 'urn:li:fs_miniSchool:20987',
#      'active': True,
#      'schoolName': 'Irvine Valley College',
#      'trackingId': 'S54H6qFzSWKcPaXOnMMbag==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C4D0BAQECK4_vLFR0lQ/company-logo_'},
#     'grade': 'GPA 3.8',
#     'timePeriod': {'endDate': {'year': 2015}, 'startDate': {'year': 2013}},
#     'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100693',
#     'degreeName': 'Associate of Science - AS',
#     'schoolName': 'Irvine Valley College',
#     'fieldOfStudy': 'Mathematics',
#     'degreeUrn': 'urn:li:fs_degree:112',
#     'schoolUrn': 'urn:li:fs_miniSchool:20987'},
#    {'entityUrn': 'urn:li:fs_education:(ACoAABjdcuQBA7y0TXDys3gcfVPB_CzFdkyRokw,456356258)',
#     'timePeriod': {'endDate': {'year': 2012}, 'startDate': {'year': 2009}},
#     'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100761',
#     'schoolName': 'Mianyang high school',
#     'degreeUrn': 'urn:li:fs_degree:200'}]},
#  {'industryName': 'Internet',
#   'lastName': 'He',
#   'locationName': 'United States',
#   'student': False,
#   'geoCountryName': 'United States',
#   'geoCountryUrn': 'urn:li:fs_geo:103644278',
#   'geoLocationBackfilled': True,
#   'elt': False,
#   'industryUrn': 'urn:li:fs_industry:6',
#   'firstName': 'Hanxiao',
#   'entityUrn': 'urn:li:fs_profile:ACoAACPl5VMBEy1V6h9JD9IxtIY_PG3AqV2Kmho',
#   'geoLocation': {'geoUrn': 'urn:li:fs_geo:90000084'},
#   'geoLocationName': 'San Francisco Bay Area',
#   'location': {'basicLocation': {'countryCode': 'us'}},
#   'headline': 'Software Engineer at Google',
#   'profile_id': 'ACoAACPl5VMBEy1V6h9JD9IxtIY_PG3AqV2Kmho',
#   'experience': [{'locationName': 'Mountain View',
#     'entityUrn': 'urn:li:fs_position:(ACoAACPl5VMBEy1V6h9JD9IxtIY_PG3AqV2Kmho,1427628452)',
#     'geoLocationName': 'Mountain View',
#     'companyName': 'Google',
#     'timePeriod': {'startDate': {'month': 2, 'year': 2019}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Internet']},
#     'title': 'Software Engineer',
#     'companyUrn': 'urn:li:fs_miniCompany:1441',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C4D0BAQHiNSL4Or29cg/company-logo_'},
#    {'locationName': 'Mountain View',
#     'entityUrn': 'urn:li:fs_position:(ACoAACPl5VMBEy1V6h9JD9IxtIY_PG3AqV2Kmho,1332497898)',
#     'geoLocationName': 'Mountain View',
#     'companyName': 'Google',
#     'timePeriod': {'endDate': {'month': 9, 'year': 2018},
#      'startDate': {'month': 6, 'year': 2018}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Internet']},
#     'title': 'Software Engineer Internship',
#     'companyUrn': 'urn:li:fs_miniCompany:1441',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C4D0BAQHiNSL4Or29cg/company-logo_'},
#    {'locationName': 'Shanghai City, China',
#     'entityUrn': 'urn:li:fs_position:(ACoAACPl5VMBEy1V6h9JD9IxtIY_PG3AqV2Kmho,1092966255)',
#     'geoLocationName': 'Shanghai City, China',
#     'geoUrn': 'urn:li:fs_geo:100460093',
#     'companyName': 'YITUTech',
#     'timePeriod': {'endDate': {'month': 4, 'year': 2017},
#      'startDate': {'month': 8, 'year': 2016}},
#     'company': {'employeeCountRange': {'start': 501, 'end': 1000},
#      'industries': ['Information Technology and Services']},
#     'title': 'Software Engineer Internship',
#     'region': 'urn:li:fs_region:(cn,8909)',
#     'companyUrn': 'urn:li:fs_miniCompany:18049607',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C510BAQHT9u6s_sxRsA/company-logo_'}],
#   'skills': [{'name': 'C++'},
#    {'name': 'C'},
#    {'name': 'Bash'},
#    {'name': 'Python'},
#    {'name': 'MatLab'},
#    {'name': 'Vim'},
#    {'name': 'Git'},
#    {'name': 'Verilog'},
#    {'name': 'VHDL'},
#    {'name': 'Java'},
#    {'name': 'Machine Learning'},
#    {'name': 'Linux'},
#    {'name': 'Artificial Intelligence (AI)'},
#    {'name': 'Matlab'}],
#   'education': [{'entityUrn': 'urn:li:fs_education:(ACoAACPl5VMBEy1V6h9JD9IxtIY_PG3AqV2Kmho,453369574)',
#     'school': {'objectUrn': 'urn:li:school:17954',
#      'entityUrn': 'urn:li:fs_miniSchool:17954',
#      'active': True,
#      'schoolName': 'University of California San Diego',
#      'trackingId': 'j3gpWRqxSTemn3gzpKN/vg==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C560BAQHQYa-3EY_aaQ/company-logo_'},
#     'timePeriod': {'endDate': {'year': 2018}, 'startDate': {'year': 2017}},
#     'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100189',
#     'degreeName': 'Master of Science - MS',
#     'schoolName': 'University of California San Diego',
#     'fieldOfStudy': 'Computer Science',
#     'degreeUrn': 'urn:li:fs_degree:626',
#     'schoolUrn': 'urn:li:fs_miniSchool:17954'},
#    {'entityUrn': 'urn:li:fs_education:(ACoAACPl5VMBEy1V6h9JD9IxtIY_PG3AqV2Kmho,453370019)',
#     'school': {'objectUrn': 'urn:li:school:11319',
#      'entityUrn': 'urn:li:fs_miniSchool:11319',
#      'active': True,
#      'schoolName': 'Shanghai Jiao Tong University',
#      'trackingId': 'Z2I8qkMzQAur5bfLbwN04Q==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C4E0BAQFkNUM4pr0xcg/company-logo_'},
#     'timePeriod': {'endDate': {'year': 2017}, 'startDate': {'year': 2013}},
#     'degreeName': 'Bachelor of Science - BS',
#     'schoolName': 'Shanghai Jiao Tong University',
#     'fieldOfStudy': 'Information Engineering',
#     'degreeUrn': 'urn:li:fs_degree:400',
#     'schoolUrn': 'urn:li:fs_miniSchool:11319'},
#    {'entityUrn': 'urn:li:fs_education:(ACoAACPl5VMBEy1V6h9JD9IxtIY_PG3AqV2Kmho,486835663)',
#     'school': {'objectUrn': 'urn:li:school:19657',
#      'entityUrn': 'urn:li:fs_miniSchool:19657',
#      'active': True,
#      'schoolName': 'University of Washington',
#      'trackingId': '1EPbXymsSLOSdTzyP8Qi1Q==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C4D0BAQEMmhF9TqUCgA/company-logo_'},
#     'timePeriod': {'endDate': {'year': 2015}, 'startDate': {'year': 2015}},
#     'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100351',
#     'degreeName': 'Summer School',
#     'schoolName': 'University of Washington',
#     'fieldOfStudy': 'Electrical and Electronics Engineering',
#     'schoolUrn': 'urn:li:fs_miniSchool:19657'}]},
#  {'industryName': 'Internet',
#   'lastName': 'Shen',
#   'locationName': 'San Diego, California',
#   'student': False,
#   'geoCountryName': 'United States',
#   'geoCountryUrn': 'urn:li:fs_geo:103644278',
#   'geoLocationBackfilled': True,
#   'elt': False,
#   'industryUrn': 'urn:li:fs_industry:6',
#   'firstName': 'Bingyu',
#   'entityUrn': 'urn:li:fs_profile:ACoAABrvAsYBMDrjsrWwvAZanYxVvZ5Z9kxSEfc',
#   'geoLocation': {'geoUrn': 'urn:li:fs_geo:103918656'},
#   'geoLocationName': 'San Diego, California',
#   'location': {'preferredGeoPlace': 'urn:li:fs_city:(us,7-1-0-37-41)',
#    'basicLocation': {'countryCode': 'us'}},
#   'headline': 'PhD Student',
#   'profile_id': 'ACoAABrvAsYBMDrjsrWwvAZanYxVvZ5Z9kxSEfc',
#   'experience': [{'locationName': 'Greater San Diego Area',
#     'entityUrn': 'urn:li:fs_position:(ACoAABrvAsYBMDrjsrWwvAZanYxVvZ5Z9kxSEfc,1437560839)',
#     'geoLocationName': 'Greater San Diego Area',
#     'geoUrn': 'urn:li:fs_geo:100737633',
#     'companyName': 'University of California San Diego',
#     'timePeriod': {'startDate': {'month': 9, 'year': 2017}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Higher Education']},
#     'title': 'Graduate Research Assistant',
#     'region': 'urn:li:fs_region:(us,732)',
#     'companyUrn': 'urn:li:fs_miniCompany:3382',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C560BAQHQYa-3EY_aaQ/company-logo_'},
#    {'locationName': 'East Palo Alto',
#     'entityUrn': 'urn:li:fs_position:(ACoAABrvAsYBMDrjsrWwvAZanYxVvZ5Z9kxSEfc,1520624681)',
#     'geoLocationName': 'East Palo Alto',
#     'companyName': 'Amazon Web Services (AWS)',
#     'timePeriod': {'endDate': {'month': 9, 'year': 2019},
#      'startDate': {'month': 6, 'year': 2019}},
#     'description': 'Worked on sub-seconds health monitoring for Amazon Aurora Multi-master database.\n\nhttps://aws.amazon.com/about-aws/whats-new/2019/08/amazon-aurora-multimaster-now-generally-available/',
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Information Technology and Services']},
#     'title': 'Software Engineer Intern',
#     'companyUrn': 'urn:li:fs_miniCompany:2382910',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C4D0BAQGzuSBRRRuphw/company-logo_'},
#    {'locationName': 'Greater San Diego Area',
#     'entityUrn': 'urn:li:fs_position:(ACoAABrvAsYBMDrjsrWwvAZanYxVvZ5Z9kxSEfc,1437560885)',
#     'geoLocationName': 'Greater San Diego Area',
#     'geoUrn': 'urn:li:fs_geo:100737633',
#     'companyName': 'University of California San Diego',
#     'timePeriod': {'endDate': {'month': 12, 'year': 2018},
#      'startDate': {'month': 9, 'year': 2018}},
#     'description': 'I was a teaching assistant for CSE120 - Operating System, a senior undergraduate class. I was responsible for leading discussion sections, maintaining project code base, grading homework and exams. ',
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Higher Education']},
#     'title': 'Teaching Assistant',
#     'region': 'urn:li:fs_region:(us,732)',
#     'companyUrn': 'urn:li:fs_miniCompany:3382',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C560BAQHQYa-3EY_aaQ/company-logo_'},
#    {'locationName': 'Toronto, Canada Area',
#     'entityUrn': 'urn:li:fs_position:(ACoAABrvAsYBMDrjsrWwvAZanYxVvZ5Z9kxSEfc,1520625715)',
#     'geoLocationName': 'Toronto, Canada Area',
#     'geoUrn': 'urn:li:fs_geo:90009551',
#     'companyName': 'York University',
#     'timePeriod': {'endDate': {'month': 9, 'year': 2016},
#      'startDate': {'month': 6, 'year': 2016}},
#     'description': 'Worked on traffic flow prediction for the intelligent transportation project. Funded by Mitacs Globalink.\n\nhttp://cvst.ca/',
#     'company': {'employeeCountRange': {'start': 5001, 'end': 10000},
#      'industries': ['Higher Education']},
#     'title': 'Research Intern',
#     'region': 'urn:li:fs_region:(ca,4876)',
#     'companyUrn': 'urn:li:fs_miniCompany:167012',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C510BAQEIk-TS5Fd-CA/company-logo_'}],
#   'skills': [{'name': 'C++',
#     'standardizedSkillUrn': 'urn:li:fs_miniSkill:198',
#     'standardizedSkill': {'name': 'C++',
#      'entityUrn': 'urn:li:fs_miniSkill:198'}},
#    {'name': 'Python',
#     'standardizedSkillUrn': 'urn:li:fs_miniSkill:1346',
#     'standardizedSkill': {'name': 'Python (Programming Language)',
#      'entityUrn': 'urn:li:fs_miniSkill:1346'}},
#    {'name': 'Linux',
#     'standardizedSkillUrn': 'urn:li:fs_miniSkill:301',
#     'standardizedSkill': {'name': 'Linux',
#      'entityUrn': 'urn:li:fs_miniSkill:301'}},
#    {'name': 'LaTeX',
#     'standardizedSkillUrn': 'urn:li:fs_miniSkill:6420',
#     'standardizedSkill': {'name': 'LaTeX',
#      'entityUrn': 'urn:li:fs_miniSkill:6420'}},
#    {'name': 'Distributed Systems',
#     'standardizedSkillUrn': 'urn:li:fs_miniSkill:1136',
#     'standardizedSkill': {'name': 'Distributed Systems',
#      'entityUrn': 'urn:li:fs_miniSkill:1136'}},
#    {'name': 'SQL'}],
#   'education': [{'entityUrn': 'urn:li:fs_education:(ACoAABrvAsYBMDrjsrWwvAZanYxVvZ5Z9kxSEfc,449308917)',
#     'school': {'objectUrn': 'urn:li:school:17954',
#      'entityUrn': 'urn:li:fs_miniSchool:17954',
#      'active': True,
#      'schoolName': 'University of California San Diego',
#      'trackingId': 'raJZtDMsTH+TMEZz6SpTOg==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C560BAQHQYa-3EY_aaQ/company-logo_'},
#     'grade': '4.0/4.0',
#     'timePeriod': {'endDate': {'year': 2023}, 'startDate': {'year': 2017}},
#     'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100189',
#     'degreeName': 'Doctor of Philosophy - PhD',
#     'schoolName': 'University of California San Diego',
#     'fieldOfStudy': 'Computer Science',
#     'degreeUrn': 'urn:li:fs_degree:900',
#     'schoolUrn': 'urn:li:fs_miniSchool:17954'},
#    {'entityUrn': 'urn:li:fs_education:(ACoAABrvAsYBMDrjsrWwvAZanYxVvZ5Z9kxSEfc,305320466)',
#     'school': {'objectUrn': 'urn:li:school:11319',
#      'entityUrn': 'urn:li:fs_miniSchool:11319',
#      'active': True,
#      'schoolName': 'Shanghai Jiao Tong University',
#      'trackingId': 'OP9brE6wSXmWvUd3CVTwkA==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C4E0BAQFkNUM4pr0xcg/company-logo_'},
#     'grade': '3.8/4.0',
#     'timePeriod': {'endDate': {'year': 2017}, 'startDate': {'year': 2013}},
#     'description': 'Academic Excellence Scholarship (top10%), 2014 - 2016\nSangsung Scholarship, 2015\nTung OOCL Scholarship, 2014\nABB Jürgen Dormann Scholarship, 2014 - 2016',
#     'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100189',
#     'degreeName': "Bachelor's degree",
# ...
#   'experience': [{'locationName': 'San Diego, CA, United States',
#     'entityUrn': 'urn:li:fs_position:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,1528842130)',
#     'geoLocationName': 'San Diego, CA, United States',
#     'companyName': 'Qualcomm Institute - UCSD Division of Calit2',
#     'timePeriod': {'startDate': {'month': 10, 'year': 2019}},
#     'description': 'Research on 3D reconstruction from multiple views.',
#     'company': {'employeeCountRange': {'start': 51, 'end': 200},
#      'industries': ['Telecommunications']},
#     'title': 'Research Assistant',
#     'companyUrn': 'urn:li:fs_miniCompany:18821546',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C560BAQE_OfWPLSPWaQ/company-logo_'},
#    {'locationName': 'Beijing City, China',
#     'entityUrn': 'urn:li:fs_position:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,1461944474)',
#     'geoLocationName': 'Beijing City, China',
#     'geoUrn': 'urn:li:fs_geo:103873152',
#     'companyName': 'ViaX Online Education',
#     'timePeriod': {'endDate': {'month': 8, 'year': 2019},
#      'startDate': {'month': 5, 'year': 2019}},
#     'description': "Designed and taught Python/R and Math/Statistics courses for bridging students into academic researches programs, which instructed by or advised under professors, postdoctoral scientists, or senior Ph.D. students at the world's Top30 universities. ",
#     'company': {'employeeCountRange': {'start': 51, 'end': 200},
#      'industries': ['E-Learning']},
#     'title': 'Teaching Assistant',
#     'region': 'urn:li:fs_region:(cn,8911)',
#     'companyUrn': 'urn:li:fs_miniCompany:13671635',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C510BAQGSclufmqJgaA/company-logo_'},
#    {'locationName': 'Remote',
#     'entityUrn': 'urn:li:fs_position:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,832218696)',
#     'geoLocationName': 'Remote',
#     'companyName': 'Udacity',
#     'timePeriod': {'endDate': {'month': 8, 'year': 2018},
#      'startDate': {'month': 7, 'year': 2016}},
#     'organizations': ['urn:li:fs_organization:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,1936921550)'],
#     'description': "Graded and guided students' projects to help them to complete Machine Learning Nanodegree. \nProvided additional guidance from the statistical perspective, such as PCA, ANOVA, LDA/QDA, Survival Analysis, Shrinkage Structured Variance, Empirical Bayes, and Time Series Analysis.",
#     'company': {'employeeCountRange': {'start': 201, 'end': 500},
#      'industries': ['E-Learning']},
#     'title': 'Code Reviewer (Machine Learning Nanodegree Team)',
#     'companyUrn': 'urn:li:fs_miniCompany:2475568',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C560BAQFDzz9y3n5Cjw/company-logo_'},
#    {'locationName': 'Remote',
#     'entityUrn': 'urn:li:fs_position:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,1509645471)',
#     'geoLocationName': 'Remote',
#     'companyName': 'Synced 机器之心',
#     'timePeriod': {'endDate': {'month': 1, 'year': 2018},
#      'startDate': {'month': 1, 'year': 2017}},
#     'description': 'Formulated research reviews on in-depth artificial intelligence and published on https://syncedreview.com/\nCompleted a research review for the paper which obtained the AAAI-17 Classic Paper Award: \n”AAAI-17 Monte Carlo Localization: Efficient Position Estimation for Robots.”',
#     'company': {'employeeCountRange': {'start': 51, 'end': 200},
#      'industries': ['Media Production']},
#     'title': 'Global Technical Analyst',
#     'companyUrn': 'urn:li:fs_miniCompany:10253612',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C4E0BAQF6CjfKwt9GFw/company-logo_'},
#    {'courses': ['urn:li:fs_course:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,1571328202)'],
#     'locationName': 'Beijing City, China',
#     'projects': ['urn:li:fs_project:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,931710686)'],
#     'entityUrn': 'urn:li:fs_position:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,752908794)',
#     'geoLocationName': 'Beijing City, China',
#     'companyName': 'Huidi Investment',
#     'timePeriod': {'endDate': {'month': 7, 'year': 2016},
#      'startDate': {'month': 10, 'year': 2015}},
#     'description': 'Managed investment products by using trading strategies and risk management. \nStudied algorithmic trading strategies and monitored risky orders arrival.\nBuilt and test an internal trading simulation system based on real queuing systems and various orders to track order flows and summarize functions to simplify writing strategies.',
#     'company': {'employeeCountRange': {'start': 11, 'end': 50},
#      'industries': ['Internet']},
#     'title': 'Quantitative Researcher',
#     'companyUrn': 'urn:li:fs_miniCompany:7584347',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C560BAQGVFtQjNBqXog/company-logo_'}],
#   'skills': [{'name': 'Data Analysis'},
#    {'name': 'Financial Modeling'},
#    {'name': 'Derivatives'},
#    {'name': 'JavaScript'},
#    {'name': 'Node.js'},
#    {'name': 'HTML/CSS'},
#    {'name': 'Python'},
#    {'name': 'R'}],
#   'education': [{'projects': ['urn:li:fs_project:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,2089953431)'],
#     'entityUrn': 'urn:li:fs_education:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,600727274)',
#     'school': {'objectUrn': 'urn:li:school:17954',
#      'entityUrn': 'urn:li:fs_miniSchool:17954',
#      'active': True,
#      'schoolName': 'University of California San Diego',
#      'trackingId': 'dgOP4/qIQ2Cil6Lt+dYePA==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C560BAQHQYa-3EY_aaQ/company-logo_'},
#     'activities': 'Contextual Robotics Institute',
#     'timePeriod': {'endDate': {'year': 2021}, 'startDate': {'year': 2019}},
#     'description': 'MATH274: Numerical Methods\nMATH271: Numerical Optimization\nCSE252A: Computer Vision I\nCSE250A: Principles of AI: Probabilistic Learning\nCSE258: Recommend Systems and Web Mining',
#     'degreeName': 'MS',
#     'schoolName': 'University of California San Diego',
#     'fieldOfStudy': 'Computitional Science (CSME)',
#     'schoolUrn': 'urn:li:fs_miniSchool:17954'},
#    {'courses': ['urn:li:fs_course:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,175)',
#      'urn:li:fs_course:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,198)',
#      'urn:li:fs_course:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,212)',
#      'urn:li:fs_course:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,1571328197)',
#      'urn:li:fs_course:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,1571328201)'],
#     'projects': ['urn:li:fs_project:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,583263839)',
#      'urn:li:fs_project:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,1571328193)'],
#     'entityUrn': 'urn:li:fs_education:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,228296309)',
#     'school': {'objectUrn': 'urn:li:school:17926',
#      'entityUrn': 'urn:li:fs_miniSchool:17926',
#      'active': True,
#      'schoolName': 'Stanford University',
#      'trackingId': '/to2Rvs7TVCds1sQIngCug==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C4D0BAQFVZxF7TIA0Ug/company-logo_'},
#     'grade': '4.0',
#     'timePeriod': {'endDate': {'year': 2015}, 'startDate': {'year': 2014}},
#     'description': 'STATS237: Theory of Investment Portfolios and Derivative Securities\nSTATS240: Statistical Methods in Finance\nSTATS242: Algorithmic Trading and Quantitative Strategists \nSTATS243: Financial Models and Statistical Methods in Risk Management \nCS106X: Programming Abstractions in C++',
#     'degreeName': 'Graduate Certificate',
#     'schoolName': 'Stanford University',
#     'fieldOfStudy': 'Quantitative Methods in Finance',
#     'schoolUrn': 'urn:li:fs_miniSchool:17926'},
#    {'entityUrn': 'urn:li:fs_education:(ACoAAAcvYS4B7izVEF1MGTv-S-3GviaG-eCBWO4,247190240)',
#     'school': {'objectUrn': 'urn:li:school:11400',
#      'entityUrn': 'urn:li:fs_miniSchool:11400',
#      'active': True,
#      'schoolName': 'University of International Business and Economics',
#      'trackingId': 'xgq2jZPYTtOEolSp7+GQrw==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C4D0BAQG4FuzUgESVsg/company-logo_'},
#     'grade': '3.9',
#     'timePeriod': {'endDate': {'year': 2014}, 'startDate': {'year': 2012}},
#     'description': "Master's Thesis (with outstanding dissertation honor):\nAutoregressive Conditional Duration with Generalized Autoregressive Conditional Heteroskedasticity (ACD-GARCH) for Irregularly Spaced High-Frequency Financial Data in Market Microstructures. ",
#     'degreeName': 'MS',
#     'schoolName': 'University of International Business and Economics',
#     'fieldOfStudy': 'Finance (Honor)',
#     'schoolUrn': 'urn:li:fs_miniSchool:11400'}]},
#  {'summary': 'Experienced Officer with a demonstrated history of working in the non-profit organization management industry. Skilled in Microsoft Word, Project Management, Microsoft Excel, Microsoft Office. Strong professional with a Bachelor of Science - BS focused on Applied Mathematics from UCSD. ',
#   'industryName': 'Financial Services',
#   'lastName': 'He',
#   'locationName': 'La Jolla, California',
#   'student': False,
#   'geoCountryName': 'United States',
#   'geoCountryUrn': 'urn:li:fs_geo:103644278',
#   'geoLocationBackfilled': True,
#   'elt': False,
#   'industryUrn': 'urn:li:fs_industry:43',
#   'firstName': 'Yijun (Olivia)',
#   'entityUrn': 'urn:li:fs_profile:ACoAAB8Fb1UBl0kYaMy3VlUythBRc6xTKAwSTng',
#   'geoLocation': {'geoUrn': 'urn:li:fs_geo:100737633'},
#   'geoLocationName': 'San Diego County, California',
#   'location': {'preferredGeoPlace': 'urn:li:fs_city:(us,7-1-0-37-24)',
#    'basicLocation': {'countryCode': 'us'}},
#   'headline': 'Analyst Summer Intern at NewDo Venture',
#   'displayPictureUrl': 'https://media.licdn.com/dms/image/C5603AQHkODNW8ZtVXw/profile-displayphoto-shrink_',
#   'profile_id': 'ACoAAB8Fb1UBl0kYaMy3VlUythBRc6xTKAwSTng',
#   'experience': [{'locationName': 'San Francisco Bay Area',
#     'entityUrn': 'urn:li:fs_position:(ACoAAB8Fb1UBl0kYaMy3VlUythBRc6xTKAwSTng,1485365454)',
#     'geoLocationName': 'San Francisco Bay Area',
#     'geoUrn': 'urn:li:fs_geo:90000084',
#     'companyName': 'NewDo Venture',
#     'timePeriod': {'startDate': {'month': 7, 'year': 2019}},
#     'company': {'employeeCountRange': {'start': 2, 'end': 10},
#      'industries': ['Venture Capital & Private Equity']},
#     'title': 'Analyst Summer Intern',
#     'region': 'urn:li:fs_region:(us,84)',
#     'companyUrn': 'urn:li:fs_miniCompany:10200350',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C4D0BAQHmhIcP8Z7ewA/company-logo_'},
#    {'locationName': 'United States',
#     'entityUrn': 'urn:li:fs_position:(ACoAAB8Fb1UBl0kYaMy3VlUythBRc6xTKAwSTng,1367125797)',
#     'geoLocationName': 'United States',
#     'geoUrn': 'urn:li:fs_geo:103644278',
#     'companyName': 'Chinese Business Society at UCSD',
#     'timePeriod': {'startDate': {'month': 3, 'year': 2018}},
#     'company': {'employeeCountRange': {'start': 51, 'end': 200},
#      'industries': ['Nonprofit Organization Management']},
#     'title': 'Officer',
#     'region': 'urn:li:fs_region:(us,0)',
#     'companyUrn': 'urn:li:fs_miniCompany:18067278',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C4E0BAQEtrsC7Rkuaeg/company-logo_'},
#    {'locationName': 'Greater San Diego Area',
#     'entityUrn': 'urn:li:fs_position:(ACoAAB8Fb1UBl0kYaMy3VlUythBRc6xTKAwSTng,1463750922)',
#     'geoLocationName': 'Greater San Diego Area',
#     'geoUrn': 'urn:li:fs_geo:100737633',
#     'companyName': 'University of California San Diego',
#     'timePeriod': {'endDate': {'month': 3, 'year': 2019},
#      'startDate': {'month': 1, 'year': 2019}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Higher Education']},
#     'title': 'Mathmetics Department Reader',
#     'region': 'urn:li:fs_region:(us,732)',
#     'companyUrn': 'urn:li:fs_miniCompany:3382',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C560BAQHQYa-3EY_aaQ/company-logo_'},
#    {'locationName': 'Menlo Park, CA',
#     'entityUrn': 'urn:li:fs_position:(ACoAAB8Fb1UBl0kYaMy3VlUythBRc6xTKAwSTng,1365089854)',
#     'geoLocationName': 'Menlo Park, CA',
#     'companyName': 'Gopher Asset',
#     'timePeriod': {'endDate': {'month': 9, 'year': 2018},
#      'startDate': {'month': 8, 'year': 2018}},
#     'description': 'Analyzed financials of 3-4 investment ideas in the Consumer, Fintech, and Healthcare industry and supported industry research.\nPrepared fundraising materials for the partners and received positive feedbacks.',
#     'company': {'employeeCountRange': {'start': 201, 'end': 500},
#      'industries': ['Investment Management']},
#     'title': 'Venture Capital Analyst',
#     'companyUrn': 'urn:li:fs_miniCompany:6659426',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C510BAQElpYdin899KQ/company-logo_'},
#    {'locationName': 'Hangzhou, Zhejiang, China',
#     'entityUrn': 'urn:li:fs_position:(ACoAAB8Fb1UBl0kYaMy3VlUythBRc6xTKAwSTng,1369785007)',
#     'geoLocationName': 'Hangzhou, Zhejiang, China',
#     'geoUrn': 'urn:li:fs_geo:90009563',
#     'companyName': 'Citi',
#     'timePeriod': {'endDate': {'month': 4, 'year': 2016},
#      'startDate': {'month': 3, 'year': 2016}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Financial Services']},
#     'title': 'Marketing And Development Intern',
#     'region': 'urn:li:fs_region:(cn,8931)',
#     'companyUrn': 'urn:li:fs_miniCompany:11448',
#     'companyLogoUrl': 'https://media.licdn.com/dms/image/C4E0BAQH4zCGEKlJ-qA/company-logo_'}],
#   'skills': [{'name': 'Microsoft Office'},
#    {'name': 'Microsoft Word'},
#    {'name': 'Microsoft PowerPoint'},
#    {'name': 'Research'},
#    {'name': 'Project Management'},
#    {'name': 'Microsoft Excel'}],
#   'education': [{'entityUrn': 'urn:li:fs_education:(ACoAAB8Fb1UBl0kYaMy3VlUythBRc6xTKAwSTng,593729686)',
#     'school': {'objectUrn': 'urn:li:school:17950',
#      'entityUrn': 'urn:li:fs_miniSchool:17950',
#      'active': True,
#      'schoolName': 'University of California, Los Angeles',
#      'trackingId': 'mn1owDR0T9KQjUO3LeDnLg==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C560BAQHaEKA3OirIlg/company-logo_'},
#     'timePeriod': {'endDate': {'year': 2021}, 'startDate': {'year': 2019}},
#     'degreeName': 'Bachelor of Science - BS',
#     'schoolName': 'University of California, Los Angeles',
#     'fieldOfStudy': 'Mathematics and Economics',
#     'degreeUrn': 'urn:li:fs_degree:400',
#     'schoolUrn': 'urn:li:fs_miniSchool:17950'},
#    {'entityUrn': 'urn:li:fs_education:(ACoAAB8Fb1UBl0kYaMy3VlUythBRc6xTKAwSTng,503992429)',
#     'school': {'objectUrn': 'urn:li:school:17954',
#      'entityUrn': 'urn:li:fs_miniSchool:17954',
#      'active': True,
#      'schoolName': 'University of California San Diego',
#      'trackingId': '0TOfEdQVQqm4NqYxkpIXbQ==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C560BAQHQYa-3EY_aaQ/company-logo_'},
#     'timePeriod': {'endDate': {'year': 2019}, 'startDate': {'year': 2017}},
#     'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100698',
#     'degreeName': 'Bachelor of Science - BS',
#     'schoolName': 'University of California San Diego',
#     'fieldOfStudy': 'Applied Mathematics',
#     'degreeUrn': 'urn:li:fs_degree:400',
#     'schoolUrn': 'urn:li:fs_miniSchool:17954'},
#    {'entityUrn': 'urn:li:fs_education:(ACoAAB8Fb1UBl0kYaMy3VlUythBRc6xTKAwSTng,553327840)',
#     'school': {'objectUrn': 'urn:li:school:12881',
#      'entityUrn': 'urn:li:fs_miniSchool:12881',
#      'active': True,
#      'schoolName': 'The University of Hong Kong',
#      'trackingId': 'yBirY2eaSZ6Vxp9q9BgG+w==',
#      'logoUrl': 'https://media.licdn.com/dms/image/C4D0BAQEubCTgcfA2sQ/company-logo_'},
#     'grade': 'A+',
#     'timePeriod': {'endDate': {'year': 2018}, 'startDate': {'year': 2018}},
#     'description': 'Attend the program Global Business in Asia. \nAnalyzing the current business environment in Asia (especially in Hong Kong and mainland China).\nProvide marketing and promotion strategies. ',
#     'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:101466',
#     'degreeName': 'Summer Exchange Program',
#     'schoolName': 'The University of Hong Kong',
#     'fieldOfStudy': 'International Business/Trade/Commerce',
#     'honors': ['urn:li:fs_honor:(ACoAAB8Fb1UBl0kYaMy3VlUythBRc6xTKAwSTng,946815615)'],
#     'schoolUrn': 'urn:li:fs_miniSchool:12881'}]}]

# %%
import json
with open('143dataanother146.json','w') as f:
    for d in pro_list:
        j = json.dumps(d)
        f.writelines(j)
        f.writelines('\n')

# %%
len(pro_list)
# Out:
# 252
